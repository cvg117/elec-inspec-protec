# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 12]  

# House shapefiles
wi_house_shp = 'data/geo/wi_2018/wi_2018.shp'
pa_house_shp = 'data/geo/pa_2018/pa_2018.shp'
mn_house_shp = 'data/geo/mn_2018/mn_2018.shp'
mi_house_shp = 'data/geo/mi_2018/mi_2018.shp'

# Census 2020 VTD shapefiles
wi_vtd_shp = 'data/geo/tl_2020_55_vtd20/tl_2020_55_vtd20.shp'
pa_vtd_shp = 'data/geo/tl_2020_42_vtd20/tl_2020_42_vtd20.shp'
mn_vtd_shp = 'data/geo/tl_2020_27_vtd20/tl_2020_27_vtd20.shp'
mi_vtd_shp = 'data/geo/tl_2020_26_vtd20/tl_2020_26_vtd20.shp'
# Out:
# /Users/victor/Desktop/capp30254/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
mn_house_gdf = gp.read_file(mn_house_shp)
mn_house_gdf[['COUNTYNAME', 'COUNTYFIPS', 'VTDID', 'PCTNAME', 'PCTCODE', 'SHORTLABEL',
       'MCDNAME', 'MCDCODE', 'MCDFIPS', 'MCDGNIS']]
# Out:
#            COUNTYNAME COUNTYFIPS      VTDID            PCTNAME PCTCODE  \
# 0              Aitkin        001  270010005             Aitkin    0005
# 1              Aitkin        001  270010010         Aitkin Twp    0010
# 2              Aitkin        001  270010015     Ball Bluff Twp    0015
# 3              Aitkin        001  270010020         Balsam Twp    0020
# 4              Aitkin        001  270010025         Beaver Twp    0025
# ...               ...        ...        ...                ...     ...
# 4108  Yellow Medicine        173  271730145  Swede Prairie Twp    0145
# 4109  Yellow Medicine        173  271730150           Tyro Twp    0150
# 4110  Yellow Medicine        173  271730155      Wergeland Twp    0155
# 4111  Yellow Medicine        173  271730160          Wood Lake    0160
# 4112  Yellow Medicine        173  271730165      Wood Lake Twp    0165
#
#      SHORTLABEL            MCDNAME MCDCODE MCDFIPS   MCDGNIS
# 0          None             Aitkin     004   00460  02393894
# 1          None         Aitkin Twp     005   00478  00663389
# 2          None     Ball Bluff Twp     015   03358  00663498
# 3          None         Balsam Twp     020   03412  00663499
# 4          None         Beaver Twp     025   04384  00663536
# ...         ...                ...     ...     ...       ...
# 4108       None  Swede Prairie Twp     120   63850  00665753
# 4109       None           Tyro Twp     125   66082  00665832
# 4110       None      Wergeland Twp     130   69160  00665953
# 4111       None          Wood Lake     134   71446  02397362
# 4112       None      Wood Lake Twp     135   71464  00666041
#
# [4113 rows x 10 columns]

# %%
# Use 'PCTNAME' to match with column 'precinct' in house data
mn_house_gdf['PCTNAME'] = mn_house_gdf['PCTNAME'].str.upper()
# Out:
#   COUNTYNAME COUNTYFIPS      VTDID         PCTNAME PCTCODE SHORTLABEL  \
# 0     Aitkin        001  270010005          AITKIN    0005       None
# 1     Aitkin        001  270010010      AITKIN TWP    0010       None
# 2     Aitkin        001  270010015  BALL BLUFF TWP    0015       None
# 3     Aitkin        001  270010020      BALSAM TWP    0020       None
# 4     Aitkin        001  270010025      BEAVER TWP    0025       None
#
#           MCDNAME MCDCODE MCDFIPS   MCDGNIS  ... G18AUDRMYH G18AUDDBLA  \
# 0          Aitkin     004   00460  02393894  ...        381        338
# 1      Aitkin Twp     005   00478  00663389  ...        299        141
# 2  Ball Bluff Twp     015   03358  00663498  ...         80         66
# 3      Balsam Twp     020   03412  00663499  ...          9         10
# 4      Beaver Twp     025   04384  00663536  ...         12         20
#
#   G18AUDMFOR G18AUDLDOC G18AUDOWRI  G18ATGRWAR  G18ATGDELL  G18ATGMJOH  \
# 0         56         18          0         414         326          60
# 1         17         10          0         312         137          24
# 2          9          0          0          79          66           9
# 3          0          0          0          10          10           0
# 4          4          0          0          12          21           2
#
#    G18ATGOWRI                                           geometry
# 0           3  POLYGON ((447378.031 5154733.389, 448085.138 5...
# 1           1  MULTIPOLYGON (((445904.069 5151658.489, 445903...
# 2           0  POLYGON ((485475.521 5207980.031, 485475.766 5...
# 3           0  POLYGON ((495441.473 5188825.678, 495423.020 5...
# 4           0  POLYGON ((495765.091 5140614.891, 494153.670 5...
#
# [5 rows x 44 columns]

# %%
wi_house_gdf = gp.read_file(wi_house_shp)
wi_house_gdf[['OBJECTID_1', 'CNTY_FIPS', 'CNTY_NAME', 'COUSUBFP', 'MCD_FIPS',
       'MCD_NAME', 'WARDID', 'LABEL']]
# Out:
#       OBJECTID_1 CNTY_FIPS CNTY_NAME COUSUBFP    MCD_FIPS    MCD_NAME WARDID  \
# 0              1     55001     ADAMS    00275  5500100275       Adams   0001
# 1              2     55001     ADAMS    00275  5500100275       Adams   0002
# 2              3     55001     ADAMS    00275  5500100275       Adams   0003
# 3              4     55001     ADAMS    00275  5500100275       Adams   0004
# 4              5     55001     ADAMS    00300  5500100300       ADAMS   0001
# ...          ...       ...       ...      ...         ...         ...    ...
# 6970        2965     55073  MARATHON    00100  5507300100  Abbotsford   0001
# 6971        3005     55073  MARATHON    36325  5507336325        HULL   0001
# 6972        2980     55073  MARATHON    16150  5507316150       Colby   0001
# 6973         625     55019     CLARK    20450  5501920450  Dorchester   0001
# 6974         655     55019     CLARK    50175  5501950175    MAYVILLE   0001
#
#                     LABEL
# 0          Adams - C 0001
# 1          Adams - C 0002
# 2          Adams - C 0003
# 3          Adams - C 0004
# 4          Adams - T 0001
# ...                   ...
# 6970  Abbotsford - C 0001
# 6971        Hull - T 0001
# 6972       Colby - C 0001
# 6973  Dorchester - V 0001
# 6974    Mayville - T 0001
#
# [6975 rows x 8 columns]

# %%
mi_vtd_gdf = gp.read_file(mi_vtd_shp)
mi_house_gdf = gp.read_file(mi_house_shp)

# %%
mi_house_gdf.sort_values(by = ['PRECINCTID'], inplace = True)
mi_house_gdf.head()
# Out:
#    OBJECTID          PRECINCTID  ELECTIONYE COUNTYFIPS MCDFIPS WARD PRECINCT  \
# 0         1  WP-001-01040-00001        2018        001   01040   00      001
# 1         2  WP-001-12460-00001        2018        001   12460   00      001
# 2         3  WP-001-19320-00001        2018        001   19320   00      001
# 3         4  WP-001-34820-00001        2018        001   34820   00      001
# 4         5  WP-001-35740-00001        2018        001   35740   00      001
#
#      ShapeSTAre    ShapeSTLen                     precinct_2  ...  G18UBRNABR  \
# 0  1.701076e+08  73869.558748     001-ALCONA TOWNSHIP-0-0001  ...           7
# 1  1.880860e+08  76737.144518  001-CALEDONIA TOWNSHIP-0-0001  ...           5
# 2  1.833231e+08  57470.528359     001-CURTIS TOWNSHIP-0-0001  ...           9
# 3  6.767958e+07  32987.191075  001-GREENBUSH TOWNSHIP-0-0001  ...          14
# 4  9.281010e+07  38642.299469     001-GUSTIN TOWNSHIP-0-0001  ...           5
#
#    G18UBRRDUN  G18UBRRNIC  G18UBRDBAR  G18UBRDKUM  G18UBRLELG  G18UBRLHAR  \
# 0         375         355         181         160           7          11
# 1         302         275         151         130           5           6
# 2         258         234         173         138          12           9
# 3         340         319         216         189          12          12
# 4         152         155          72          56           6           5
#
#    G18UBRTSCH  G18UBRTSOS                                           geometry
# 0          19           9  POLYGON ((713885.576 472642.367, 713798.715 47...
# 1          24          11  POLYGON ((686272.607 476273.249, 685978.453 47...
# 2          29          16  POLYGON ((686986.253 442623.144, 686677.696 44...
# 3          20          12  POLYGON ((712947.018 443503.339, 712791.603 44...
# 4          17           7  POLYGON ((705992.472 452886.004, 704976.166 45...
#
# [5 rows x 70 columns]

# %%
# Only interested in a subset of columns for the purpose of matching
to_keep = ['OBJECTID', 'PRECINCTID', 'COUNTYFIPS', 'MCDFIPS', 'WARD',
       'PRECINCT', 'ShapeSTAre', 'ShapeSTLen', 'precinct_2', 'geometry']
mi_house_gdf = mi_house_gdf[to_keep]

# %%
#Exploring whether COUNTYFIPS + MCDFIPS + WARD + PRECINCT in house matches NAME20 in census
mi_house_gdf['NAME20'] = mi_house_gdf['COUNTYFIPS'] + mi_house_gdf['MCDFIPS'] + mi_house_gdf['WARD'] + mi_house_gdf['PRECINCT']
mi_house_gdf[['NAME20', 'COUNTYFIPS', 'MCDFIPS', 'WARD', 'PRECINCT']]
mi_house_gdf.sort_values(by=['NAME20'], inplace = True)

# %%
mi_house_gdf['NAME20_dup'] = mi_house_gdf.duplicated(subset=['NAME20'], keep = False)
mi_house_gdf[mi_house_gdf['NAME20_dup'] == True]
# Out:
#       OBJECTID          PRECINCTID COUNTYFIPS MCDFIPS WARD PRECINCT  \
# 4774      4775  WP-099-50480-00009        099   50480   00      009
# 4775      4776  WP-099-50480-00036        099   50480   00      009
# 4776      4777  WP-099-50480-00024        099   50480   00      024
# 4777      4778  WP-099-50480-00037        099   50480   00      024
# 3551      3552  WP-161-03000-01009        161   03000   01      009
# 4767      4768  WP-161-03000-01011        161   03000   01      009
#
#         ShapeSTAre    ShapeSTLen                  precinct_2  \
# 4774  8.495685e+06  15437.357551  099-MACOMB TOWNSHIP-0-0009
# 4775  2.139211e+06   6776.945641  099-MACOMB TOWNSHIP-0-0036
# 4776  3.198090e+06   9785.372429  099-MACOMB TOWNSHIP-0-0024
# 4777  1.954170e+07  19750.695866  099-MACOMB TOWNSHIP-0-0037
# 3551  1.733960e+06   7290.267025   161-ANN ARBOR CITY-1-0009
# 4767  1.303841e+06   6667.777777   161-ANN ARBOR CITY-1-0011
#
#                                                geometry         NAME20  \
# 4774  POLYGON ((753950.400 241300.865, 753751.818 24...  0995048000009
# 4775  POLYGON ((752091.306 244506.512, 751849.622 24...  0995048000009
# 4776  POLYGON ((756375.070 239120.253, 756396.948 23...  0995048000024
# 4777  POLYGON ((757099.600 244068.134, 757138.312 24...  0995048000024
# 3551  POLYGON ((688407.863 198273.555, 688408.878 19...  1610300001009
# 4767  POLYGON ((687399.194 198829.835, 687583.991 19...  1610300001009
#
#       NAME20_dup
# 4774        True
# 4775        True
# 4776        True
# 4777        True
# 3551        True
# 4767        True

# %%
mi_vtd_gdf.head()
# Out:
#   STATEFP20 COUNTYFP20 VTDST20      GEOID20 VTDI20         NAME20  \
# 0        26        003  003001  26003003001      A  0030446000001
# 1        26        003  003007  26003003007      A  0035622000001
# 2        26        003  003010  26003003010      A  0036916000001
# 3        26        003  003005  26003003005      A  0035236000001
# 4        26        003  003009  26003003009      A  0036082000001
#
#                       NAMELSAD20 LSAD20 MTFCC20 FUNCSTAT20    ALAND20  \
# 0  Voting District 0030446000001     V1   G5240          N  366843585
# 1  Voting District 0035622000001     V1   G5240          N  523821819
# 2  Voting District 0036916000001     V1   G5240          N  208983301
# 3  Voting District 0035236000001     V1   G5240          N  183058104
# 4  Voting District 0036082000001     V1   G5240          N  227225602
#
#    AWATER20   INTPTLAT20    INTPTLON20  \
# 0  43425964  +46.3380932  -086.7739238
# 1  40068222  +46.4024760  -086.5105746
# 2    652387  +46.3468839  -086.9948981
# 3   3482479  +46.2149640  -086.8698593
# 4  41073935  +46.4536416  -086.9688367
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.72267 46.48484, -86.72254 ...
# 1  POLYGON ((-86.67879 46.38334, -86.67877 46.383...
# 2  POLYGON ((-87.11651 46.39118, -87.10728 46.391...
# 3  POLYGON ((-86.99081 46.23156, -86.99077 46.235...
# 4  POLYGON ((-87.11662 46.49507, -87.11651 46.499...

# %%
# Drop rows where VTD has ZZZ
print(mi_vtd_gdf.shape)
remove = mi_vtd_gdf['GEOID20'].str.contains('Z')
mi_vtd_gdf = mi_vtd_gdf[ ~remove]
print(mi_vtd_gdf.shape)
# Out:
# (4805, 15)
# (4765, 15)

# %%
mi_vtd_gdf.sort_values(by = ['NAME20'], inplace = True)
mi_vtd_gdf['NAME20_dup'] = mi_vtd_gdf.duplicated(subset=['NAME20'], keep = False)
mi_vtd_gdf[mi_vtd_gdf['NAME20_dup'] == True]
# Out:
#      STATEFP20 COUNTYFP20 VTDST20      GEOID20 VTDI20         NAME20  \
# 1383        26        027  001001  26027001001      A  0215776001001
# 4376        26        021  021036  26021021036      A  0215776001001
# 1737        26        073  000001  26073000001      A  0351592000001
# 2734        26        035  035002  26035035002      A  0351592000001
# 3238        26        155  000001  26155000001      A  0376186000001
# 1711        26        037  037025  26037037025      A  0376186000001
# 4566        26        045  045034  26045045034      A  0453342000002
# 1719        26        037  000002  26037000002      A  0453342000002
# 4661        26        093  000002  26093000002      A  0492776000002
# 2630        26        049  049039  26049049039      A  0492776000002
# 770         26        125  000002  26125000002      A  0492776000002
# 3836        26        065  065073  26065065073      A  0654600004042
# 78          26        037  004042  26037004042      A  0654600004042
# 1399        26        147  000001  26147000001      P  0996838000001
# 3891        26        099  099159  26099099159      A  0996838000001
# 3774        26        111  111025  26111111025      A  1115378001004
# 330         26        017  001004  26017001004      A  1115378001004
# 1453        26        147  147062  26147147062      A  1476584000004
# 1449        26        147  147061  26147147061      A  1476584000004
# 723         26        151  151004  26151151004      A  1511118000001
# 4638        26        087  000001  26087000001      A  1511118000001
# 2324        26        163  163654  26163163654      A  1632836000003
# 3106        26        115  000003  26115000003      A  1632836000003
#
#                          NAMELSAD20 LSAD20 MTFCC20 FUNCSTAT20   ALAND20  \
# 1383  Voting District 0215776001001     V1   G5240          N   1665725
# 4376  Voting District 0215776001001     V1   G5240          N   4999890
# 1737  Voting District 0351592000001     V1   G5240          N   1500894
# 2734  Voting District 0351592000001     V1   G5240          N   7826243
# 3238  Voting District 0376186000001     V1   G5240          N     85039
# 1711  Voting District 0376186000001     V1   G5240          N   2509646
# 4566  Voting District 0453342000002     V1   G5240          N   3205684
# 1719  Voting District 0453342000002     V1   G5240          N    805515
# 4661  Voting District 0492776000002     V1   G5240          N    228708
# 2630  Voting District 0492776000002     V1   G5240          N   2393962
# 770   Voting District 0492776000002     V1   G5240          N     33690
# 3836  Voting District 0654600004042     V1   G5240          N   3445897
# 78    Voting District 0654600004042     V1   G5240          N   7613434
# 1399  Voting District 0996838000001     V1   G5240          S    640876
# 3891  Voting District 0996838000001     V1   G5240          N   3383701
# 3774  Voting District 1115378001004     V1   G5240          N   4781032
# 330   Voting District 1115378001004     V1   G5240          N     82368
# 1453  Voting District 1476584000004     V1   G5240          N  10841833
# 1449  Voting District 1476584000004     V1   G5240          N   9993398
# 723   Voting District 1511118000001     V1   G5240          N   2819461
# 4638  Voting District 1511118000001     V1   G5240          N    102832
# 2324  Voting District 1632836000003     V1   G5240          N   1800091
# 3106  Voting District 1632836000003     V1   G5240          N      5780
#
#       AWATER20   INTPTLAT20    INTPTLON20  \
# 1383         0  +41.8773833  -086.2024195
# 4376     92916  +41.8459674  -086.2347446
# 1737       845  +43.8085221  -084.7605779
# 2734    281587  +43.8278810  -084.7617591
# 3238     79424  +42.9979130  -084.3662259
# 1711      3984  +43.0030847  -084.3758869
# 4566    128258  +42.7607878  -084.7437519
# 1719         0  +42.7752784  -084.7291630
# 4661         0  +42.7812454  -083.6944507
# 2630    258504  +42.7858329  -083.6958231
# 770          0  +42.7897535  -083.6853927
# 3836     55313  +42.7614240  -084.5662096
# 78       24066  +42.7813463  -084.5783378
# 1399         0  +42.8094843  -082.7303890
# 3891         0  +42.8164826  -082.7603937
# 3774     53837  +43.6195912  -084.1797725
# 330          0  +43.6151814  -084.1647424
# 1453         0  +42.9511428  -082.4772547
# 1449    544878  +42.9851714  -082.4642013
# 723       4038  +43.2112385  -082.9854775
# 4638         0  +43.2133443  -083.0012410
# 2324     19201  +42.0972472  -083.2782908
# 3106       761  +42.0899203  -083.2860269
#
#                                                geometry  NAME20_dup
# 1383  MULTIPOLYGON (((-86.22412 41.85948, -86.22411 ...        True
# 4376  POLYGON ((-86.26834 41.84124, -86.26832 41.841...        True
# 1737  MULTIPOLYGON (((-84.77287 43.81470, -84.77276 ...        True
# 2734  MULTIPOLYGON (((-84.74771 43.82582, -84.74764 ...        True
# 3238  MULTIPOLYGON (((-84.36657 42.99868, -84.36619 ...        True
# 1711  POLYGON ((-84.38169 43.01131, -84.37949 43.011...        True
# 4566  POLYGON ((-84.75939 42.76625, -84.75555 42.766...        True
# 1719  POLYGON ((-84.73953 42.77656, -84.73814 42.776...        True
# 4661  POLYGON ((-83.69967 42.78306, -83.69148 42.783...        True
# 2630  POLYGON ((-83.71635 42.78290, -83.71625 42.782...        True
# 770   POLYGON ((-83.68672 42.79043, -83.68435 42.790...        True
# 3836  POLYGON ((-84.58893 42.76977, -84.58426 42.769...        True
# 78    POLYGON ((-84.60281 42.77124, -84.60275 42.772...        True
# 1399  POLYGON ((-82.73435 42.81406, -82.72572 42.814...        True
# 3891  POLYGON ((-82.77487 42.82363, -82.77091 42.823...        True
# 3774  POLYGON ((-84.18742 43.61659, -84.18742 43.618...        True
# 330   POLYGON ((-84.16744 43.61495, -84.16743 43.616...        True
# 1453  POLYGON ((-82.50193 42.95180, -82.50131 42.952...        True
# 1449  POLYGON ((-82.49006 42.96923, -82.48998 42.969...        True
# 723   MULTIPOLYGON (((-82.97899 43.20516, -82.97864 ...        True
# 4638  MULTIPOLYGON (((-83.00035 43.20909, -83.00016 ...        True
# 2324  POLYGON ((-83.28696 42.08900, -83.28686 42.089...        True
# 3106  POLYGON ((-83.28631 42.08915, -83.28630 42.089...        True

# %%
# Note: 
# Census geometry and house geometry have different CRS
# need to reproject house
mi_vtd_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
mi_house_gdf.crs
# Out:
# <Derived Projected CRS: EPSG:3078>
# Name: NAD83 / Michigan Oblique Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Michigan.
# - bounds: (-90.42, 41.69, -82.13, 48.32)
# Coordinate Operation:
# - name: Michigan Oblique Mercator (meters)
# - method: Hotine Oblique Mercator (variant A)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# Reproject house boundary to match census
epsg_crs = 'EPSG:4269'
mi_house_rp_gdf  = mi_house_gdf.to_crs(epsg_crs)

# %%
mi_vtd_precinct = mi_vtd_gdf.merge(mi_house_rp_gdf, on = 'NAME20')
mi_vtd_precinct.head()
# Out:
#   STATEFP20 COUNTYFP20 VTDST20      GEOID20 VTDI20         NAME20  \
# 0        26        001  001001  26001001001      A  0010104000001
# 1        26        001  001002  26001001002      A  0011246000001
# 2        26        001  001003  26001001003      A  0011932000001
# 3        26        001  001004  26001001004      A  0013482000001
# 4        26        001  001005  26001001005      A  0013574000001
#
#                       NAMELSAD20 LSAD20 MTFCC20 FUNCSTAT20  ...  \
# 0  Voting District 0010104000001     V1   G5240          N  ...
# 1  Voting District 0011246000001     V1   G5240          N  ...
# 2  Voting District 0011932000001     V1   G5240          N  ...
# 3  Voting District 0013482000001     V1   G5240          N  ...
# 4  Voting District 0013574000001     V1   G5240          N  ...
#
#            PRECINCTID  COUNTYFIPS MCDFIPS WARD PRECINCT    ShapeSTAre  \
# 0  WP-001-01040-00001         001   01040   00      001  1.701076e+08
# 1  WP-001-12460-00001         001   12460   00      001  1.880860e+08
# 2  WP-001-19320-00001         001   19320   00      001  1.833231e+08
# 3  WP-001-34820-00001         001   34820   00      001  6.767958e+07
# 4  WP-001-35740-00001         001   35740   00      001  9.281010e+07
#
#      ShapeSTLen                     precinct_2  \
# 0  73869.558748     001-ALCONA TOWNSHIP-0-0001
# 1  76737.144518  001-CALEDONIA TOWNSHIP-0-0001
# 2  57470.528359     001-CURTIS TOWNSHIP-0-0001
# 3  32987.191075  001-GREENBUSH TOWNSHIP-0-0001
# 4  38642.299469     001-GUSTIN TOWNSHIP-0-0001
#
#                                           geometry_y NAME20_dup_y
# 0  POLYGON ((-83.29467 44.77345, -83.29577 44.773...        False
# 1  POLYGON ((-83.64206 44.81382, -83.64578 44.813...        False
# 2  POLYGON ((-83.64530 44.51090, -83.64918 44.510...        False
# 3  POLYGON ((-83.31858 44.51164, -83.32053 44.511...        False
# 4  POLYGON ((-83.40226 44.59805, -83.41507 44.598...        False
#
# [5 rows x 27 columns]

# %%
 mi_vtd_precinct.shape
# Out:
# (4692, 27)

# %%
mi_vtd_precinct.columns
# Out:
# Index(['STATEFP20', 'COUNTYFP20', 'VTDST20', 'GEOID20', 'VTDI20', 'NAME20',
#        'NAMELSAD20', 'LSAD20', 'MTFCC20', 'FUNCSTAT20', 'ALAND20', 'AWATER20',
#        'INTPTLAT20', 'INTPTLON20', 'geometry_x', 'NAME20_dup_x', 'OBJECTID',
#        'PRECINCTID', 'COUNTYFIPS', 'MCDFIPS', 'WARD', 'PRECINCT', 'ShapeSTAre',
#        'ShapeSTLen', 'precinct_2', 'geometry_y', 'NAME20_dup_y'],
#       dtype='object')

# %%
vtd = gp.GeoSeries(mi_vtd_precinct['geometry_x'])
house = gp.GeoSeries(mi_vtd_precinct['geometry_y'])

# %%
vtd.overlaps(house, align = True).value_counts()
# Out:
# True     4654
# False      38
# dtype: int64

# %%
vtd.intersects(house, align = True).value_counts()
# Out:
# True     4657
# False      35
# dtype: int64

# %%
mi_vtd_precinct_geo = gp.sjoin(mi_vtd_gdf, mi_house_rp_gdf, how = 'left', predicate = 'overlaps')

# %%
mi_vtd_precinct_geo.head()
# Out:
#      STATEFP20 COUNTYFP20 VTDST20      GEOID20 VTDI20    NAME20_left  \
# 4516        26        001  001001  26001001001      A  0010104000001
# 4516        26        001  001001  26001001001      A  0010104000001
# 4516        26        001  001001  26001001001      A  0010104000001
# 4516        26        001  001001  26001001001      A  0010104000001
# 4516        26        001  001001  26001001001      A  0010104000001
#
#                          NAMELSAD20 LSAD20 MTFCC20 FUNCSTAT20  ...  \
# 4516  Voting District 0010104000001     V1   G5240          N  ...
# 4516  Voting District 0010104000001     V1   G5240          N  ...
# 4516  Voting District 0010104000001     V1   G5240          N  ...
# 4516  Voting District 0010104000001     V1   G5240          N  ...
# 4516  Voting District 0010104000001     V1   G5240          N  ...
#
#               PRECINCTID  COUNTYFIPS MCDFIPS WARD PRECINCT    ShapeSTAre  \
# 4516  WP-001-01040-00001         001   01040   00      001  1.701076e+08
# 4516  WP-001-37380-00001         001   37380   00      001  9.069045e+07
# 4516  WP-007-71240-00001         007   71240   00      001  1.133428e+08
# 4516  WP-001-37220-00001         001   37220   00      001  1.849065e+08
# 4516  WP-001-12460-00001         001   12460   00      001  1.880860e+08
#
#         ShapeSTLen                     precinct_2   NAME20_right  \
# 4516  73869.558748     001-ALCONA TOWNSHIP-0-0001  0010104000001
# 4516  40569.226537     001-HAYNES TOWNSHIP-0-0001  0013738000001
# 4516  55359.476448    007-SANBORN TOWNSHIP-0-0001  0077124000001
# 4516  57640.898324      001-HAWES TOWNSHIP-0-0001  0013722000001
# 4516  76737.144518  001-CALEDONIA TOWNSHIP-0-0001  0011246000001
#
#      NAME20_dup_right
# 4516            False
# 4516            False
# 4516            False
# 4516            False
# 4516            False
#
# [5 rows x 28 columns]

# %%
mi_vtd_precinct_geo.shape, mi_vtd_precinct.shape
# Out:
# ((29883, 28), (4692, 27))

# %%
# Compare results of merge on 'NAME20' with results of sjon overlaps
mi_comparison = mi_vtd_precinct.merge(mi_vtd_precinct_geo, on = 'GEOID20')

# %%
mi_comparison.columns
# Out:
# Index(['STATEFP20_x', 'COUNTYFP20_x', 'VTDST20_x', 'GEOID20', 'VTDI20_x',
#        'NAME20', 'NAMELSAD20_x', 'LSAD20_x', 'MTFCC20_x', 'FUNCSTAT20_x',
#        'ALAND20_x', 'AWATER20_x', 'INTPTLAT20_x', 'INTPTLON20_x', 'geometry_x',
#        'NAME20_dup_x', 'OBJECTID_x', 'PRECINCTID_x', 'COUNTYFIPS_x',
#        'MCDFIPS_x', 'WARD_x', 'PRECINCT_x', 'ShapeSTAre_x', 'ShapeSTLen_x',
#        'precinct_2_x', 'geometry_y', 'NAME20_dup_y', 'STATEFP20_y',
#        'COUNTYFP20_y', 'VTDST20_y', 'VTDI20_y', 'NAME20_left', 'NAMELSAD20_y',
#        'LSAD20_y', 'MTFCC20_y', 'FUNCSTAT20_y', 'ALAND20_y', 'AWATER20_y',
#        'INTPTLAT20_y', 'INTPTLON20_y', 'geometry', 'NAME20_dup_left',
#        'index_right', 'OBJECTID_y', 'PRECINCTID_y', 'COUNTYFIPS_y',
#        'MCDFIPS_y', 'WARD_y', 'PRECINCT_y', 'ShapeSTAre_y', 'ShapeSTLen_y',
#        'precinct_2_y', 'NAME20_right', 'NAME20_dup_right'],
#       dtype='object')

# %%
mi_comparison['match'] = mi_comparison['PRECINCTID_x'].eq(mi_comparison['PRECINCTID_y'])
mi_comparison['match'].value_counts()
# Out:
# False    24786
# True      4654
# Name: match, dtype: int64

# %%
mi_comparison[['GEOID20', 'PRECINCTID_x', 'PRECINCTID_y', 'precinct_2_x', 'precinct_2_y', 'match']]
# Out:
#            GEOID20        PRECINCTID_x        PRECINCTID_y  \
# 0      26001001001  WP-001-01040-00001  WP-001-01040-00001
# 1      26001001001  WP-001-01040-00001  WP-001-37380-00001
# 2      26001001001  WP-001-01040-00001  WP-007-71240-00001
# 3      26001001001  WP-001-01040-00001  WP-001-37220-00001
# 4      26001001001  WP-001-01040-00001  WP-001-12460-00001
# ...            ...                 ...                 ...
# 29435  26165165021  WP-165-86500-00001  WP-165-36420-00001
# 29436  26165165021  WP-165-86500-00001  WP-165-75940-00001
# 29437  26165165021  WP-165-86500-00001  WP-165-86500-00001
# 29438  26165165021  WP-165-86500-00001  WP-101-16380-00001
# 29439  26165165021  WP-165-86500-00001  WP-055-34240-00001
#
#                       precinct_2_x                     precinct_2_y  match
# 0       001-ALCONA TOWNSHIP-0-0001       001-ALCONA TOWNSHIP-0-0001   True
# 1       001-ALCONA TOWNSHIP-0-0001       001-HAYNES TOWNSHIP-0-0001  False
# 2       001-ALCONA TOWNSHIP-0-0001      007-SANBORN TOWNSHIP-0-0001  False
# 3       001-ALCONA TOWNSHIP-0-0001        001-HAWES TOWNSHIP-0-0001  False
# 4       001-ALCONA TOWNSHIP-0-0001    001-CALEDONIA TOWNSHIP-0-0001  False
# ...                            ...                              ...    ...
# 29435  165-WEXFORD TOWNSHIP-0-0001      165-HANOVER TOWNSHIP-0-0001  False
# 29436  165-WEXFORD TOWNSHIP-0-0001  165-SPRINGVILLE TOWNSHIP-0-0001  False
# 29437  165-WEXFORD TOWNSHIP-0-0001      165-WEXFORD TOWNSHIP-0-0001   True
# 29438  165-WEXFORD TOWNSHIP-0-0001        101-CLEON TOWNSHIP-0-0001  False
# 29439  165-WEXFORD TOWNSHIP-0-0001        055-GRANT TOWNSHIP-0-0001  False
#
# [29440 rows x 6 columns]

# %%
mi_to_export = mi_comparison[mi_comparison['match'] == True]

# %%
mi_to_export.columns
# Out:
# Index(['STATEFP20_x', 'COUNTYFP20_x', 'VTDST20_x', 'GEOID20', 'VTDI20_x',
#        'NAME20', 'NAMELSAD20_x', 'LSAD20_x', 'MTFCC20_x', 'FUNCSTAT20_x',
#        'ALAND20_x', 'AWATER20_x', 'INTPTLAT20_x', 'INTPTLON20_x', 'geometry_x',
#        'NAME20_dup_x', 'OBJECTID_x', 'PRECINCTID_x', 'COUNTYFIPS_x',
#        'MCDFIPS_x', 'WARD_x', 'PRECINCT_x', 'ShapeSTAre_x', 'ShapeSTLen_x',
#        'precinct_2_x', 'geometry_y', 'NAME20_dup_y', 'STATEFP20_y',
#        'COUNTYFP20_y', 'VTDST20_y', 'VTDI20_y', 'NAME20_left', 'NAMELSAD20_y',
#        'LSAD20_y', 'MTFCC20_y', 'FUNCSTAT20_y', 'ALAND20_y', 'AWATER20_y',
#        'INTPTLAT20_y', 'INTPTLON20_y', 'geometry', 'NAME20_dup_left',
#        'index_right', 'OBJECTID_y', 'PRECINCTID_y', 'COUNTYFIPS_y',
#        'MCDFIPS_y', 'WARD_y', 'PRECINCT_y', 'ShapeSTAre_y', 'ShapeSTLen_y',
#        'precinct_2_y', 'NAME20_right', 'NAME20_dup_right', 'match'],
#       dtype='object')

# %%
# To match with House csv we could use jurisdiction_name or jurisdiction_fips
# jurisdiction_name
# jurisdiction_fips
mi_to_export['jurisdiction_name'] = mi_to_export['precinct_2_x'].str.split('-', 3, expand = True)[1]
mi_to_export['jurisdiction_fips'] = mi_to_export['STATEFP20_x'] + mi_to_export['COUNTYFIPS_x'] + mi_to_export['MCDFIPS_x']
mi_to_export[['jurisdiction_name', 'jurisdiction_fips']]
# Out:
# /var/folders/sn/cp78km453yq1y8g3c822ww7r0000gn/T/ipykernel_42985/1178360062.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mi_to_export['jurisdiction_name'] = mi_to_export['precinct_2_x'].str.split('-', 3, expand = True)[1]
# /var/folders/sn/cp78km453yq1y8g3c822ww7r0000gn/T/ipykernel_42985/1178360062.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mi_to_export['jurisdiction_fips'] = mi_to_export['STATEFP20_x'] + mi_to_export['COUNTYFIPS_x'] + mi_to_export['MCDFIPS_x']
#            jurisdiction_name jurisdiction_fips
# 0            ALCONA TOWNSHIP        2600101040
# 7         CALEDONIA TOWNSHIP        2600112460
# 12           CURTIS TOWNSHIP        2600119320
# 19        GREENBUSH TOWNSHIP        2600134820
# 22           GUSTIN TOWNSHIP        2600135740
# ...                      ...               ...
# 29413         SELMA TOWNSHIP        2616572380
# 29420        SLAGLE TOWNSHIP        2616574220
# 29426  SOUTH BRANCH TOWNSHIP        2616574820
# 29431   SPRINGVILLE TOWNSHIP        2616575940
# 29437       WEXFORD TOWNSHIP        2616586500
#
# [4654 rows x 2 columns]

# %%
mi_to_export.columns
# Out:
# Index(['STATEFP20_x', 'COUNTYFP20_x', 'VTDST20_x', 'GEOID20', 'VTDI20_x',
#        'NAME20', 'NAMELSAD20_x', 'LSAD20_x', 'MTFCC20_x', 'FUNCSTAT20_x',
#        'ALAND20_x', 'AWATER20_x', 'INTPTLAT20_x', 'INTPTLON20_x', 'geometry_x',
#        'NAME20_dup_x', 'OBJECTID_x', 'PRECINCTID_x', 'COUNTYFIPS_x',
#        'MCDFIPS_x', 'WARD_x', 'PRECINCT_x', 'ShapeSTAre_x', 'ShapeSTLen_x',
#        'precinct_2_x', 'geometry_y', 'NAME20_dup_y', 'STATEFP20_y',
#        'COUNTYFP20_y', 'VTDST20_y', 'VTDI20_y', 'NAME20_left', 'NAMELSAD20_y',
#        'LSAD20_y', 'MTFCC20_y', 'FUNCSTAT20_y', 'ALAND20_y', 'AWATER20_y',
#        'INTPTLAT20_y', 'INTPTLON20_y', 'geometry', 'NAME20_dup_left',
#        'index_right', 'OBJECTID_y', 'PRECINCTID_y', 'COUNTYFIPS_y',
#        'MCDFIPS_y', 'WARD_y', 'PRECINCT_y', 'ShapeSTAre_y', 'ShapeSTLen_y',
#        'precinct_2_y', 'NAME20_right', 'NAME20_dup_right', 'match',
#        'jurisdiction_name', 'jurisdiction_fips'],
#       dtype='object')

# %%
keep = ['STATEFP20_x', 'COUNTYFP20_x', 'VTDST20_x', 'GEOID20', 'VTDI20_x',
       'NAME20', 'NAMELSAD20_x', 'LSAD20_x', 'MTFCC20_x', 'FUNCSTAT20_x', 
       'OBJECTID_x', 'PRECINCTID_x', 'COUNTYFIPS_x',
       'MCDFIPS_x', 'WARD_x', 'PRECINCT_x', 'jurisdiction_name', 'jurisdiction_fips']
mi_to_export.to_csv('data/mi_match_vtd_house.csv', columns = keep, index = False)

# %%
mi_to_export
# Out:
#       STATEFP20_x COUNTYFP20_x VTDST20_x      GEOID20 VTDI20_x         NAME20  \
# 0              26          001    001001  26001001001        A  0010104000001
# 7              26          001    001002  26001001002        A  0011246000001
# 12             26          001    001003  26001001003        A  0011932000001
# 19             26          001    001004  26001001004        A  0013482000001
# 22             26          001    001005  26001001005        A  0013574000001
# ...           ...          ...       ...          ...      ...            ...
# 29413          26          165    165017  26165165017        A  1657238000001
# 29420          26          165    165018  26165165018        A  1657422000001
# 29426          26          165    165019  26165165019        A  1657482000001
# 29431          26          165    165020  26165165020        A  1657594000001
# 29437          26          165    165021  26165165021        A  1658650000001
#
#                         NAMELSAD20_x LSAD20_x MTFCC20_x FUNCSTAT20_x  ...  \
# 0      Voting District 0010104000001       V1     G5240            N  ...
# 7      Voting District 0011246000001       V1     G5240            N  ...
# 12     Voting District 0011932000001       V1     G5240            N  ...
# 19     Voting District 0013482000001       V1     G5240            N  ...
# 22     Voting District 0013574000001       V1     G5240            N  ...
# ...                              ...      ...       ...          ...  ...
# 29413  Voting District 1657238000001       V1     G5240            N  ...
# 29420  Voting District 1657422000001       V1     G5240            N  ...
# 29426  Voting District 1657482000001       V1     G5240            N  ...
# 29431  Voting District 1657594000001       V1     G5240            N  ...
# 29437  Voting District 1658650000001       V1     G5240            N  ...
#
#        WARD_y  PRECINCT_y  ShapeSTAre_y  ShapeSTLen_y  \
# 0          00         001  1.701076e+08  73869.558748
# 7          00         001  1.880860e+08  76737.144518
# 12         00         001  1.833231e+08  57470.528359
# 19         00         001  6.767958e+07  32987.191075
# 22         00         001  9.281010e+07  38642.299469
# ...       ...         ...           ...           ...
# 29413      00         001  9.319311e+07  38600.121308
# 29420      00         001  9.261500e+07  38556.196062
# 29426      00         001  9.328114e+07  38733.850893
# 29431      00         001  9.180714e+07  38395.113741
# 29437      00         001  9.453458e+07  38896.328885
#
#                            precinct_2_y   NAME20_right  NAME20_dup_right  \
# 0            001-ALCONA TOWNSHIP-0-0001  0010104000001             False
# 7         001-CALEDONIA TOWNSHIP-0-0001  0011246000001             False
# 12           001-CURTIS TOWNSHIP-0-0001  0011932000001             False
# 19        001-GREENBUSH TOWNSHIP-0-0001  0013482000001             False
# 22           001-GUSTIN TOWNSHIP-0-0001  0013574000001             False
# ...                                 ...            ...               ...
# 29413         165-SELMA TOWNSHIP-0-0001  1657238000001             False
# 29420        165-SLAGLE TOWNSHIP-0-0001  1657422000001             False
# 29426  165-SOUTH BRANCH TOWNSHIP-0-0001  1657482000001             False
# 29431   165-SPRINGVILLE TOWNSHIP-0-0001  1657594000001             False
# 29437       165-WEXFORD TOWNSHIP-0-0001  1658650000001             False
#
#       match      jurisdiction_name jurisdiction_fips
# 0      True        ALCONA TOWNSHIP        2600101040
# 7      True     CALEDONIA TOWNSHIP        2600112460
# 12     True        CURTIS TOWNSHIP        2600119320
# 19     True     GREENBUSH TOWNSHIP        2600134820
# 22     True        GUSTIN TOWNSHIP        2600135740
# ...     ...                    ...               ...
# 29413  True         SELMA TOWNSHIP        2616572380
# 29420  True        SLAGLE TOWNSHIP        2616574220
# 29426  True  SOUTH BRANCH TOWNSHIP        2616574820
# 29431  True   SPRINGVILLE TOWNSHIP        2616575940
# 29437  True       WEXFORD TOWNSHIP        2616586500
#
# [4654 rows x 57 columns]
